# %% [markdown]
# ## UNIVERSIDAD AUTONOMA DE AGUASCALIENTES
# ### Departamento: Centro de Ciencias Básicas
# ### César Eduardo Elias del Hoyo
# ### Curso: Metaheurística I
# ### Maestro: Francisco Javier Luna Rosas
# ### 7mo Semestre

# %% [markdown]
# # PRACTICA No 3: PSO
# ### La optimización por enjambre de partícula (PSO) es un algoritmo de optimización basado a simulación de la conducta social de organismo, como badadas de aves o bancos de peces
#
# ### En esta práctica implementamos PSO para buscar el óptimo global de una función en 2D (f(x) = x^2)

# %% [markdown]
# ## Paso 1: Importar las librerías necesarias

# %%
# Librerias
import numpy as np
import random
import matplotlib.pyplot as plt

# %% [markdown]
# ## Paso 2: Definir la función objetivo

# %%
# Funcion objetivo
def objetive_f(x):
    return x**2

# %% [markdown]
# ## Paso 3: Inicializar los parametros del PSO

# %%
# Parametros del PSo
num_particles = 30
num_dimensions = 1
num_iteraciones = 100
w = 0.5 # Factor de inercia que controla la velocidad
c1 = 1.5 # Constante cognitivia
c2 = 2.0 # Constante social

# Limites de la busqueda
bounds = (-10,10)

history_position = []

# %% [markdown]
# ## Paso 4: Inicializamos las particulas y velocidades

# %%
# Inicializar las particulas
particles = np.random.uniform(bounds[0], bounds[1], (num_particles, num_dimensions))
velocities = np.random.uniform(-1, 1, (num_particles, num_dimensions)) # Valor aleatorio entre -1 y 1

# Inicializar las mejores posiciones individuales y globales
pbest_position = particles.copy()
pbest_value = np.array([objetive_f(x) for x in particles])
gbest_position = pbest_position[np.argmin(pbest_value)] # Minimo valor de x
gbest_value = np.min(pbest_value) # Valor de la funcion par la funcion xi

# Una particula (pbest) representa x, pero x no es la solucion
# La solucion se obtiene a partir del calculo de las x

#particles

# %% [markdown]
# ## Paso 5: Implementar el ciclo principal del PSO

# %%
for t in range (num_iteraciones):
    for i in range (num_particles):
        # Evaluar la funcion objetivo
        fitness = objetive_f(particles[i])

        # Actualizar la mejor posicion individual
        if fitness < pbest_value[1]:
            pbest_value[1] = fitness
            pbest_position[i] = particles[i].copy()

        # Actualizar la mejor posicion global
        if fitness < gbest_value:
            gbest_value = fitness
            gbest_position = particles[i].copy()

    # Actualizar velocidades y posiciones
    for i in range (num_particles):
        r1 = random.random()
        r2 = random.random()

        velocities[i] = (w * velocities [i]
                         + c1 * r1 * (pbest_position[i] - particles[i])
                         + c2 * r2 * (gbest_position - particles[i]))
        
        particles[i] = particles[i] + velocities[i]

        # Respteatar los limites de la busqueda
        particles[i] = np.clip(particles[i], bounds[0], bounds[1])

    history_position.append(particles.copy()) # Para graficar
    print(f"Iteracion {t+1} / {num_iteraciones}, Mejor valor global: {gbest_value}")

print(f"Mejor posicion encontrada: {gbest_position}, con valor: {gbest_value} ")
# Out:
# Iteracion 1 / 100, Mejor valor global: 0.10126961065332431
# Iteracion 2 / 100, Mejor valor global: [0.02542735]
# Iteracion 3 / 100, Mejor valor global: [0.00020718]
# Iteracion 4 / 100, Mejor valor global: [0.00020718]
# Iteracion 5 / 100, Mejor valor global: [0.00020718]
# Iteracion 6 / 100, Mejor valor global: [0.00020718]
# Iteracion 7 / 100, Mejor valor global: [2.63005226e-05]
# Iteracion 8 / 100, Mejor valor global: [2.63005226e-05]
# Iteracion 9 / 100, Mejor valor global: [2.63005226e-05]
# Iteracion 10 / 100, Mejor valor global: [2.63005226e-05]
# Iteracion 11 / 100, Mejor valor global: [2.63005226e-05]
# Iteracion 12 / 100, Mejor valor global: [1.70275749e-06]
# Iteracion 13 / 100, Mejor valor global: [7.54242656e-07]
# Iteracion 14 / 100, Mejor valor global: [7.54242656e-07]
# Iteracion 15 / 100, Mejor valor global: [3.65921285e-08]
# Iteracion 16 / 100, Mejor valor global: [3.65921285e-08]
# Iteracion 17 / 100, Mejor valor global: [7.65496367e-09]
# Iteracion 18 / 100, Mejor valor global: [7.65496367e-09]
# Iteracion 19 / 100, Mejor valor global: [2.52157319e-11]
# Iteracion 20 / 100, Mejor valor global: [2.52157319e-11]
# Iteracion 21 / 100, Mejor valor global: [2.52157319e-11]
# Iteracion 22 / 100, Mejor valor global: [2.52157319e-11]
# Iteracion 23 / 100, Mejor valor global: [2.52157319e-11]
# Iteracion 24 / 100, Mejor valor global: [2.52157319e-11]
# Iteracion 25 / 100, Mejor valor global: [2.52157319e-11]
# Iteracion 26 / 100, Mejor valor global: [8.56488568e-12]
# Iteracion 27 / 100, Mejor valor global: [8.56488568e-12]
# Iteracion 28 / 100, Mejor valor global: [8.56488568e-12]
# Iteracion 29 / 100, Mejor valor global: [6.5618248e-12]
# Iteracion 30 / 100, Mejor valor global: [6.5618248e-12]
# Iteracion 31 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 32 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 33 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 34 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 35 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 36 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 37 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 38 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 39 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 40 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 41 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 42 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 43 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 44 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 45 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 46 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 47 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 48 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 49 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 50 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 51 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 52 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 53 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 54 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 55 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 56 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 57 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 58 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 59 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 60 / 100, Mejor valor global: [8.28521486e-16]
# Iteracion 61 / 100, Mejor valor global: [1.51751461e-17]
# Iteracion 62 / 100, Mejor valor global: [1.51751461e-17]
# Iteracion 63 / 100, Mejor valor global: [1.51751461e-17]
# Iteracion 64 / 100, Mejor valor global: [1.51751461e-17]
# Iteracion 65 / 100, Mejor valor global: [6.10286679e-22]
# Iteracion 66 / 100, Mejor valor global: [6.10286679e-22]
# Iteracion 67 / 100, Mejor valor global: [6.10286679e-22]
# Iteracion 68 / 100, Mejor valor global: [6.10286679e-22]
# Iteracion 69 / 100, Mejor valor global: [6.10286679e-22]
# Iteracion 70 / 100, Mejor valor global: [6.10286679e-22]
# Iteracion 71 / 100, Mejor valor global: [6.10286679e-22]
# Iteracion 72 / 100, Mejor valor global: [6.10286679e-22]
# Iteracion 73 / 100, Mejor valor global: [6.10286679e-22]
# Iteracion 74 / 100, Mejor valor global: [6.10286679e-22]
# Iteracion 75 / 100, Mejor valor global: [6.10286679e-22]
# Iteracion 76 / 100, Mejor valor global: [6.10286679e-22]
# Iteracion 77 / 100, Mejor valor global: [6.10286679e-22]
# Iteracion 78 / 100, Mejor valor global: [6.10286679e-22]
# Iteracion 79 / 100, Mejor valor global: [6.10286679e-22]
# Iteracion 80 / 100, Mejor valor global: [6.10286679e-22]
# Iteracion 81 / 100, Mejor valor global: [6.10286679e-22]
# Iteracion 82 / 100, Mejor valor global: [3.78799924e-23]
# Iteracion 83 / 100, Mejor valor global: [3.78799924e-23]
# Iteracion 84 / 100, Mejor valor global: [3.78799924e-23]
# Iteracion 85 / 100, Mejor valor global: [3.78799924e-23]
# Iteracion 86 / 100, Mejor valor global: [3.78799924e-23]
# Iteracion 87 / 100, Mejor valor global: [3.78799924e-23]
# Iteracion 88 / 100, Mejor valor global: [3.78799924e-23]
# Iteracion 89 / 100, Mejor valor global: [3.78799924e-23]
# Iteracion 90 / 100, Mejor valor global: [3.78799924e-23]
# Iteracion 91 / 100, Mejor valor global: [3.78799924e-23]
# Iteracion 92 / 100, Mejor valor global: [3.78799924e-23]
# Iteracion 93 / 100, Mejor valor global: [3.78799924e-23]
# Iteracion 94 / 100, Mejor valor global: [3.78799924e-23]
# Iteracion 95 / 100, Mejor valor global: [3.78799924e-23]
# Iteracion 96 / 100, Mejor valor global: [3.78799924e-23]
# Iteracion 97 / 100, Mejor valor global: [2.4979517e-25]
# Iteracion 98 / 100, Mejor valor global: [2.4979517e-25]
# Iteracion 99 / 100, Mejor valor global: [2.4979517e-25]
# Iteracion 100 / 100, Mejor valor global: [2.4979517e-25]
# Mejor posicion encontrada: [4.99795128e-13], con valor: [2.4979517e-25]

# %%
x_values=np.linspace(-10,10,400)
y_values=objetive_f(x_values)
plt.figure(figsize=(10,6))
plt.plot(x_values,y_values, label="Funcion objetivo")

# %%
x_values=np.linspace(-10,10,400)
y_values=objetive_f(x_values)
plt.figure(figsize=(10,6))
plt.plot(x_values,y_values, label="Funcion objetivo")

plt.scatter([gbest_position],[objetive_f(gbest_position)], color="red", s=100, label="Mejor solucion")

# %%
x_values=np.linspace(-10,10,400)
y_values=objetive_f(x_values)

plt.figure(figsize=(10,6))
plt.plot(x_values,y_values, label="Funcion objetivo")

for positions in history_position:
    plt.scatter(positions, objetive_f(positions), color="red", s=0.2)

plt.scatter([gbest_position],[objetive_f(gbest_position)], color="blue", s=100, label="Mejor solucion")
