# %% [markdown]
# ## UNIVERSIDAD AUTONOMA DE AGUASCALIENTES
# ### Departamento: Centro de Ciencias Básicas
# ### Jose Luis Sandoval Perez
# ### Curso: Metaheurística I
# ### Maestro: Francisco Javier Luna Rosas
# ### 7mo Semestre

# %% [markdown]
# # PRACTICA No 5: PSO
# ### La optimización por enjambre de partícula (PSO) es un algoritmo de optimización basado a simulación de la conducta social de organismo, como badadas de aves o bancos de peces
#
# ### En esta práctica implementamos PSO para buscar el óptimo global de una función en 2D (f(x) = - [1-(11/2 x - 7/2)^2] [cos(11/2 x - 7/2) +1] +2).

# %% [markdown]
# ## Paso 1: Importar las librerías necesarias

# %%
# Librerias
import numpy as np
import random
import math
import matplotlib.pyplot as plt

# %% [markdown]
# ## Paso 2: Definir la función objetivo

# %%
# Funcion objetivo
def objetive_f(x):
    return -(1-((11/2 * x) - 7/2)**2) * (np.cos((11/2 * x) - 7/2)+1)+2

# %% [markdown]
# ## Paso 3: Inicializar los parametros del PSO

# %%
# Parametros del PSo
num_particles = 30
num_dimensions = 1
num_iteraciones = 100
w = 0.5 # Factor de inercia que controla la velocidad
c1 = 1.5 # Constante cognitivia
c2 = 2.0 # Constante social

# Limites de la busqueda
bounds = (-10,10)

history_position = []

# %% [markdown]
# ## Paso 4: Inicializamos las particulas y velocidades

# %%
# Inicializar las particulas
particles = np.random.uniform(bounds[0], bounds[1], (num_particles, num_dimensions))
velocities = np.random.uniform(-1, 1, (num_particles, num_dimensions)) # Valor aleatorio entre -1 y 1

# Inicializar las mejores posiciones individuales y globales
pbest_position = particles.copy()
pbest_value = np.array([objetive_f(x) for x in particles])
gbest_position = pbest_position[np.argmin(pbest_value)] # Minimo valor de x
gbest_value = np.min(pbest_value) # Valor de la funcion par la funcion xi

# Una particula (pbest) representa x, pero x no es la solucion
# La solucion se obtiene a partir del calculo de las x

#particles

# %% [markdown]
# ## Paso 5: Implementar el ciclo principal del PSO

# %%
for t in range (num_iteraciones):
    for i in range (num_particles):
        # Evaluar la funcion objetivo
        fitness = objetive_f(particles[i])

        # Actualizar la mejor posicion individual
        if fitness < pbest_value[1]:
            pbest_value[1] = fitness
            pbest_position[i] = particles[i].copy()

        # Actualizar la mejor posicion global
        if fitness < gbest_value:
            gbest_value = fitness
            gbest_position = particles[i].copy()

    # Actualizar velocidades y posiciones
    for i in range (num_particles):
        r1 = random.random()
        r2 = random.random()

        velocities[i] = (w * velocities [i]
                         + c1 * r1 * (pbest_position[i] - particles[i])
                         + c2 * r2 * (gbest_position - particles[i]))
        
        particles[i] = particles[i] + velocities[i]

        # Respteatar los limites de la busqueda
        particles[i] = np.clip(particles[i], bounds[0], bounds[1])

    history_position.append(particles.copy()) # Para graficar
    print(f"Iteracion {t+1} / {num_iteraciones}, Mejor valor global: {gbest_value}")

print(f"Mejor posicion encontrada: {gbest_position}, con valor: {gbest_value} ")
# Out:
# Iteracion 1 / 100, Mejor valor global: 3.332053723515088
# Iteracion 2 / 100, Mejor valor global: [2.00305148]
# Iteracion 3 / 100, Mejor valor global: [0.02671677]
# Iteracion 4 / 100, Mejor valor global: [0.02671677]
# Iteracion 5 / 100, Mejor valor global: [0.02671677]
# Iteracion 6 / 100, Mejor valor global: [0.0201457]
# Iteracion 7 / 100, Mejor valor global: [0.0201457]
# Iteracion 8 / 100, Mejor valor global: [0.0201457]
# Iteracion 9 / 100, Mejor valor global: [0.0201457]
# Iteracion 10 / 100, Mejor valor global: [7.95603828e-05]
# Iteracion 11 / 100, Mejor valor global: [7.95603828e-05]
# Iteracion 12 / 100, Mejor valor global: [7.95603828e-05]
# Iteracion 13 / 100, Mejor valor global: [7.95603828e-05]
# Iteracion 14 / 100, Mejor valor global: [7.95603828e-05]
# Iteracion 15 / 100, Mejor valor global: [7.95603828e-05]
# Iteracion 16 / 100, Mejor valor global: [7.95603828e-05]
# Iteracion 17 / 100, Mejor valor global: [7.95603828e-05]
# Iteracion 18 / 100, Mejor valor global: [7.95603828e-05]
# Iteracion 19 / 100, Mejor valor global: [7.95603828e-05]
# Iteracion 20 / 100, Mejor valor global: [7.95603828e-05]
# Iteracion 21 / 100, Mejor valor global: [7.95603828e-05]
# Iteracion 22 / 100, Mejor valor global: [7.95603828e-05]
# Iteracion 23 / 100, Mejor valor global: [7.95603828e-05]
# Iteracion 24 / 100, Mejor valor global: [3.84567283e-05]
# Iteracion 25 / 100, Mejor valor global: [3.84567283e-05]
# Iteracion 26 / 100, Mejor valor global: [3.84567283e-05]
# Iteracion 27 / 100, Mejor valor global: [3.84567283e-05]
# Iteracion 28 / 100, Mejor valor global: [3.84567283e-05]
# Iteracion 29 / 100, Mejor valor global: [3.84567283e-05]
# Iteracion 30 / 100, Mejor valor global: [1.15196907e-05]
# Iteracion 31 / 100, Mejor valor global: [1.15196907e-05]
# Iteracion 32 / 100, Mejor valor global: [1.15196907e-05]
# Iteracion 33 / 100, Mejor valor global: [5.0376442e-06]
# Iteracion 34 / 100, Mejor valor global: [5.0376442e-06]
# Iteracion 35 / 100, Mejor valor global: [5.0376442e-06]
# Iteracion 36 / 100, Mejor valor global: [5.0376442e-06]
# Iteracion 37 / 100, Mejor valor global: [3.48749241e-08]
# Iteracion 38 / 100, Mejor valor global: [3.48749241e-08]
# Iteracion 39 / 100, Mejor valor global: [3.48749241e-08]
# Iteracion 40 / 100, Mejor valor global: [3.48749241e-08]
# Iteracion 41 / 100, Mejor valor global: [3.48749241e-08]
# Iteracion 42 / 100, Mejor valor global: [3.48749241e-08]
# Iteracion 43 / 100, Mejor valor global: [3.48749241e-08]
# Iteracion 44 / 100, Mejor valor global: [3.48749241e-08]
# Iteracion 45 / 100, Mejor valor global: [3.48749241e-08]
# Iteracion 46 / 100, Mejor valor global: [3.48749241e-08]
# Iteracion 47 / 100, Mejor valor global: [3.48749241e-08]
# Iteracion 48 / 100, Mejor valor global: [3.48749241e-08]
# Iteracion 49 / 100, Mejor valor global: [3.48749241e-08]
# Iteracion 50 / 100, Mejor valor global: [3.48749241e-08]
# Iteracion 51 / 100, Mejor valor global: [1.67944103e-08]
# Iteracion 52 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 53 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 54 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 55 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 56 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 57 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 58 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 59 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 60 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 61 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 62 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 63 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 64 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 65 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 66 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 67 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 68 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 69 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 70 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 71 / 100, Mejor valor global: [2.05936379e-10]
# Iteracion 72 / 100, Mejor valor global: [1.39039891e-11]
# Iteracion 73 / 100, Mejor valor global: [1.39039891e-11]
# Iteracion 74 / 100, Mejor valor global: [1.39039891e-11]
# Iteracion 75 / 100, Mejor valor global: [1.39039891e-11]
# Iteracion 76 / 100, Mejor valor global: [1.39039891e-11]
# Iteracion 77 / 100, Mejor valor global: [1.39039891e-11]
# Iteracion 78 / 100, Mejor valor global: [1.39039891e-11]
# Iteracion 79 / 100, Mejor valor global: [1.39039891e-11]
# Iteracion 80 / 100, Mejor valor global: [1.39039891e-11]
# Iteracion 81 / 100, Mejor valor global: [1.39039891e-11]
# Iteracion 82 / 100, Mejor valor global: [7.412293e-12]
# Iteracion 83 / 100, Mejor valor global: [2.23843166e-12]
# Iteracion 84 / 100, Mejor valor global: [7.79598608e-13]
# Iteracion 85 / 100, Mejor valor global: [3.32178729e-13]
# Iteracion 86 / 100, Mejor valor global: [1.78967952e-13]
# Iteracion 87 / 100, Mejor valor global: [1.19904087e-13]
# Iteracion 88 / 100, Mejor valor global: [9.50350909e-14]
# Iteracion 89 / 100, Mejor valor global: [8.34887715e-14]
# Iteracion 90 / 100, Mejor valor global: [7.79376563e-14]
# Iteracion 91 / 100, Mejor valor global: [7.52731211e-14]
# Iteracion 92 / 100, Mejor valor global: [7.39408534e-14]
# Iteracion 93 / 100, Mejor valor global: [7.32747196e-14]
# Iteracion 94 / 100, Mejor valor global: [7.3052675e-14]
# Iteracion 95 / 100, Mejor valor global: [7.3052675e-14]
# Iteracion 96 / 100, Mejor valor global: [7.3052675e-14]
# Iteracion 97 / 100, Mejor valor global: [7.3052675e-14]
# Iteracion 98 / 100, Mejor valor global: [7.3052675e-14]
# Iteracion 99 / 100, Mejor valor global: [7.3052675e-14]
# Iteracion 100 / 100, Mejor valor global: [7.3052675e-14]
# Mejor posicion encontrada: [0.63636361], con valor: [7.3052675e-14]

# %%
x_values=np.linspace(-10,10,400)
y_values=objetive_f(x_values)

plt.figure(figsize=(10,6))
plt.plot(x_values,y_values, label="Funcion objetivo")

for positions in history_position:
    plt.scatter(positions, objetive_f(positions), color="red", s=0.2)

plt.scatter([gbest_position],[objetive_f(gbest_position)], color="blue", s=100, label="Mejor solucion")
