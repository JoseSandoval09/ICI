# %% [markdown]
# ## UNIVERSIDAD AUTONOMA DE AGUASCALIENTES
# ### Departamento: Centro de Ciencias Básicas
# ### Jose Luis Sandoval Perez
# ### Curso: Metaheurística I
# ### Maestro: Francisco Javier Luna Rosas
# ### 7mo Semestre

# %% [markdown]
# # PRACTICA No 5: PSO
# ### La optimización por enjambre de partícula (PSO) es un algoritmo de optimización basado a simulación de la conducta social de organismo, como badadas de aves o bancos de peces
#
# ### En esta práctica implementamos PSO para buscar el óptimo global de una función en 2D (f(x) = - [1-(11/2 x - 7/2)^2] [cos(11/2 x - 7/2) +1] +2).

# %% [markdown]
# ## Paso 1: Importar las librerías necesarias

# %%
# Librerias
import numpy as np
import random
import math
import matplotlib.pyplot as plt

# %% [markdown]
# ## Paso 2: Definir la función objetivo

# %%
# Funcion objetivo
def objetive_f(x):
    return -(1-((11/2 * x) - 7/2)**2) * (np.cos((11/2 * x) - 7/2)+1)+2

# %% [markdown]
# ## Paso 3: Inicializar los parametros del PSO

# %%
# Parametros del PSo
num_particles = 30
num_dimensions = 1
num_iteraciones = 100
w = 0.5 # Factor de inercia que controla la velocidad
c1 = 1.5 # Constante cognitivia
c2 = 2.0 # Constante social

# Limites de la busqueda
bounds = (-10,10)

history_position = []

# %% [markdown]
# ## Paso 4: Inicializamos las particulas y velocidades

# %%
# Inicializar las particulas
particles = np.random.uniform(bounds[0], bounds[1], (num_particles, num_dimensions))
velocities = np.random.uniform(-1, 1, (num_particles, num_dimensions)) # Valor aleatorio entre -1 y 1

# Inicializar las mejores posiciones individuales y globales
pbest_position = particles.copy()
pbest_value = np.array([objetive_f(x) for x in particles])
gbest_position = pbest_position[np.argmin(pbest_value)] # Minimo valor de x
gbest_value = np.min(pbest_value) # Valor de la funcion par la funcion xi

# Una particula (pbest) representa x, pero x no es la solucion
# La solucion se obtiene a partir del calculo de las x

#particles

# %% [markdown]
# ## Paso 5: Implementar el ciclo principal del PSO

# %%
for t in range (num_iteraciones):
    for i in range (num_particles):
        # Evaluar la funcion objetivo
        fitness = objetive_f(particles[i])

        # Actualizar la mejor posicion individual
        if fitness < pbest_value[1]:
            pbest_value[1] = fitness
            pbest_position[i] = particles[i].copy()

        # Actualizar la mejor posicion global
        if fitness < gbest_value:
            gbest_value = fitness
            gbest_position = particles[i].copy()

    # Actualizar velocidades y posiciones
    for i in range (num_particles):
        r1 = random.random()
        r2 = random.random()

        velocities[i] = (w * velocities [i]
                         + c1 * r1 * (pbest_position[i] - particles[i])
                         + c2 * r2 * (gbest_position - particles[i]))
        
        particles[i] = particles[i] + velocities[i]

        # Respteatar los limites de la busqueda
        particles[i] = np.clip(particles[i], bounds[0], bounds[1])

    history_position.append(particles.copy()) # Para graficar
    print(f"Iteracion {t+1} / {num_iteraciones}, Mejor valor global: {gbest_value}")

print(f"Mejor posicion encontrada: {gbest_position}, con valor: {gbest_value} ")
# Out:
# Iteracion 1 / 100, Mejor valor global: 0.2826905628491938
# Iteracion 2 / 100, Mejor valor global: [0.25964164]
# Iteracion 3 / 100, Mejor valor global: [0.01170421]
# Iteracion 4 / 100, Mejor valor global: [0.01170421]
# Iteracion 5 / 100, Mejor valor global: [9.43238926e-07]
# Iteracion 6 / 100, Mejor valor global: [9.43238926e-07]
# Iteracion 7 / 100, Mejor valor global: [9.43238926e-07]
# Iteracion 8 / 100, Mejor valor global: [9.43238926e-07]
# Iteracion 9 / 100, Mejor valor global: [9.43238926e-07]
# Iteracion 10 / 100, Mejor valor global: [9.43238926e-07]
# Iteracion 11 / 100, Mejor valor global: [9.43238926e-07]
# Iteracion 12 / 100, Mejor valor global: [9.43238926e-07]
# Iteracion 13 / 100, Mejor valor global: [9.43238926e-07]
# Iteracion 14 / 100, Mejor valor global: [9.43238926e-07]
# Iteracion 15 / 100, Mejor valor global: [9.43238926e-07]
# Iteracion 16 / 100, Mejor valor global: [2.49283016e-09]
# Iteracion 17 / 100, Mejor valor global: [2.49283016e-09]
# Iteracion 18 / 100, Mejor valor global: [2.49283016e-09]
# Iteracion 19 / 100, Mejor valor global: [2.49283016e-09]
# Iteracion 20 / 100, Mejor valor global: [2.49283016e-09]
# Iteracion 21 / 100, Mejor valor global: [2.49283016e-09]
# Iteracion 22 / 100, Mejor valor global: [2.49283016e-09]
# Iteracion 23 / 100, Mejor valor global: [2.49283016e-09]
# Iteracion 24 / 100, Mejor valor global: [2.49283016e-09]
# Iteracion 25 / 100, Mejor valor global: [2.49283016e-09]
# Iteracion 26 / 100, Mejor valor global: [2.49283016e-09]
# Iteracion 27 / 100, Mejor valor global: [2.49283016e-09]
# Iteracion 28 / 100, Mejor valor global: [4.57704319e-10]
# Iteracion 29 / 100, Mejor valor global: [4.57704319e-10]
# Iteracion 30 / 100, Mejor valor global: [4.57704319e-10]
# Iteracion 31 / 100, Mejor valor global: [4.57704319e-10]
# Iteracion 32 / 100, Mejor valor global: [4.57704319e-10]
# Iteracion 33 / 100, Mejor valor global: [4.57704319e-10]
# Iteracion 34 / 100, Mejor valor global: [4.57704319e-10]
# Iteracion 35 / 100, Mejor valor global: [3.15351523e-10]
# Iteracion 36 / 100, Mejor valor global: [3.15351523e-10]
# Iteracion 37 / 100, Mejor valor global: [3.15351523e-10]
# Iteracion 38 / 100, Mejor valor global: [3.15351523e-10]
# Iteracion 39 / 100, Mejor valor global: [3.15351523e-10]
# Iteracion 40 / 100, Mejor valor global: [3.15351523e-10]
# Iteracion 41 / 100, Mejor valor global: [2.0484392e-10]
# Iteracion 42 / 100, Mejor valor global: [2.0484392e-10]
# Iteracion 43 / 100, Mejor valor global: [4.66906513e-11]
# Iteracion 44 / 100, Mejor valor global: [4.66906513e-11]
# Iteracion 45 / 100, Mejor valor global: [3.48718832e-11]
# Iteracion 46 / 100, Mejor valor global: [2.63178368e-11]
# Iteracion 47 / 100, Mejor valor global: [2.24913421e-11]
# Iteracion 48 / 100, Mejor valor global: [2.06910045e-11]
# Iteracion 49 / 100, Mejor valor global: [1.98190353e-11]
# Iteracion 50 / 100, Mejor valor global: [1.93898231e-11]
# Iteracion 51 / 100, Mejor valor global: [1.91771043e-11]
# Iteracion 52 / 100, Mejor valor global: [1.90711891e-11]
# Iteracion 53 / 100, Mejor valor global: [1.90183425e-11]
# Iteracion 54 / 100, Mejor valor global: [1.89919191e-11]
# Iteracion 55 / 100, Mejor valor global: [1.89785965e-11]
# Iteracion 56 / 100, Mejor valor global: [1.89719351e-11]
# Iteracion 57 / 100, Mejor valor global: [1.89690486e-11]
# Iteracion 58 / 100, Mejor valor global: [1.89672722e-11]
# Iteracion 59 / 100, Mejor valor global: [1.89666061e-11]
# Iteracion 60 / 100, Mejor valor global: [1.89659399e-11]
# Iteracion 61 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 62 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 63 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 64 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 65 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 66 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 67 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 68 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 69 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 70 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 71 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 72 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 73 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 74 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 75 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 76 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 77 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 78 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 79 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 80 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 81 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 82 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 83 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 84 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 85 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 86 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 87 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 88 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 89 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 90 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 91 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 92 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 93 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 94 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 95 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 96 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 97 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 98 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 99 / 100, Mejor valor global: [1.89657179e-11]
# Iteracion 100 / 100, Mejor valor global: [1.89657179e-11]
# Mejor posicion encontrada: [0.63636314], con valor: [1.89657179e-11]

# %%
x_values=np.linspace(-10,10,400)
y_values=objetive_f(x_values)

plt.figure(figsize=(10,6))
plt.plot(x_values,y_values, label="Funcion objetivo")

for positions in history_position:
    plt.scatter(positions, objetive_f(positions), color="red", s=0.2)

plt.scatter([gbest_position],[objetive_f(gbest_position)], color="blue", s=100, label="Mejor solucion")
